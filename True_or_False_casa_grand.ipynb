# %%
import pandas as pd

# %%
df = pd.read_excel("casagrand.xls")

# %%
text_cols = df.select_dtypes(include="object").columns
df[text_cols] = df[text_cols].fillna("")

# %%
import re
for col in ['FirstName', 'LastName']:
    df[col] = df[col].astype(str)
    df[col] = df[col].str.replace(r'[^a-zA-Z. ]', '', regex=True)

# %%
df.head(15)
# Out:
#            LastName        FirstName Salutation                         Name  \
# 0   As Chakravarthi                                          As Chakravarthi
# 1         Raveendra             Meda                          Meda Raveendra
# 2            Kannan                          Mr                       Kannan
# 3            Ramyaa                          Mr                       Ramyaa
# 4           Vasan.K                          Mr                      Vasan.K
# 5            sundar                          Mr                       sundar
# 6          Pandiyan                          Mr                     Pandiyan
# 7             K.Uma                          Mr                        K.Uma
# 8      Vinodh Kumar                                             Vinodh Kumar
# 9           Soundar                                                  Soundar
# 10      shyamsundar  Anu shyamsundar        mrs  Anu shyamsundar shyamsundar
# 11                .           Rajesh                                Rajesh .
# 12       Anoopkumar                                               Anoopkumar
# 13          Murugan                          Mr                      Murugan
# 14           harish                          Mr                       harish
#
#                         Company         Phone   MobilePhone  \
# 0               As Chakravarthi  919962154351  9.199622e+11
# 1                Meda Raveendra  919962041716  9.199620e+11
# 2                        Kannan  918189923399  9.181899e+11
# 3                        Ramyaa  919962746446  9.199627e+11
# 4                       Vasan.K  918939149522  9.189391e+11
# 5                        sundar  919962502711  9.199625e+11
# 6                      Pandiyan  919790947384  9.197909e+11
# 7                         K.Uma  919840891528  9.198409e+11
# 8                  Vinodh Kumar  919940194192  9.199402e+11
# 9                       Soundar  919677023477  9.196770e+11
# 10  Anu shyamsundar shyamsundar  919597072434  9.195971e+11
# 11                     Rajesh .  919884899946  9.198849e+11
# 12                   Anoopkumar  919894123300  9.198941e+11
# 13                      Murugan  918122331777  9.181223e+11
# 14                       harish  919884216662  9.198842e+11
#
#                               Email  SYS_Mobile__c  WA_Formatted_Phone__c  \
# 0               aschakrav@gmail.com   9.199622e+11           9.199622e+11
# 1               mrreddy@ramcadds.in   9.199620e+11           9.199620e+11
# 2         kannan.ican1891@gmail.com   9.181899e+11           9.181899e+11
# 3              ramyaa.doc@gmail.com   9.199627e+11           9.199627e+11
# 4                 vasankm@yahoo.com   9.189391e+11           9.189391e+11
# 5             ksundar2001@gmail.com   9.199625e+11           9.199625e+11
# 6                 acp3012@gmail.com   9.197909e+11           9.197909e+11
# 7                 kuma189@yahoo.com   9.198409e+11           9.198409e+11
# 8            vinoths99401@gmail.com   9.199402e+11           9.199402e+11
# 9              phyraj2008@gmail.com   9.196770e+11           9.196770e+11
# 10  ravichandran.anushuya@gmail.com   9.195971e+11           9.195971e+11
# 11                     eahk@fcp.com   9.198849e+11           9.198849e+11
# 12                ak30484@gmail.com   9.198941e+11           9.198941e+11
# 13                                    9.181223e+11           9.181223e+11
# 14         lavanya_2974@yahoo.co.in   9.198842e+11           9.198842e+11
#
#     ... Mobile8__c  Mobile9__c  Mobile10__c  Country_Code__c  First_Phone__c  \
# 0   ...        NaN         NaN          NaN             91.0      9962154351
# 1   ...        NaN         NaN          NaN             91.0      9962041716
# 2   ...        NaN         NaN          NaN             91.0      8189923399
# 3   ...        NaN         NaN          NaN             91.0      9962746446
# 4   ...        NaN         NaN          NaN             91.0      8939149522
# 5   ...        NaN         NaN          NaN             91.0      9962502711
# 6   ...        NaN         NaN          NaN             91.0      9790947384
# 7   ...        NaN         NaN          NaN             91.0      9840891528
# 8   ...        NaN         NaN          NaN             91.0      9940194192
# 9   ...        NaN         NaN          NaN             91.0      9677023477
# 10  ...        NaN         NaN          NaN             91.0      9597072434
# 11  ...        NaN         NaN          NaN             91.0      9884899946
# 12  ...        NaN         NaN          NaN             91.0      9894123300
# 13  ...        NaN         NaN          NaN             91.0      8122331777
# 14  ...        NaN         NaN          NaN             91.0      9884216662
#
#     Second_Phone__c  Third_Phone__c  Fourth_Phone__c  Sixth_Phone__c  \
# 0      9.080857e+09    8.778092e+09              NaN             NaN
# 1               NaN             NaN              NaN             NaN
# 2               NaN             NaN              NaN             NaN
# 3      9.003088e+09             NaN              NaN             NaN
# 4               NaN             NaN              NaN             NaN
# 5               NaN             NaN              NaN             NaN
# 6               NaN             NaN              NaN             NaN
# 7               NaN             NaN              NaN             NaN
# 8               NaN             NaN              NaN             NaN
# 9               NaN             NaN              NaN             NaN
# 10              NaN             NaN              NaN             NaN
# 11              NaN             NaN              NaN             NaN
# 12              NaN             NaN              NaN             NaN
# 13              NaN             NaN              NaN             NaN
# 14              NaN             NaN              NaN             NaN
#
#     Seventh_Phone__c
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# 5                NaN
# 6                NaN
# 7                NaN
# 8                NaN
# 9                NaN
# 10               NaN
# 11               NaN
# 12               NaN
# 13               NaN
# 14               NaN
#
# [15 rows x 29 columns]

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("NameValidation") \
    .getOrCreate()

# %%
spark_df = spark.createDataFrame(df)

# %%
from pyspark.sql import functions as F

spark_df = spark_df.withColumn(
    "full_name",
    F.trim(F.concat_ws(" ", F.col("FirstName"), F.col("LastName")))
)

# %%
spark_df.show(truncate=False)
# Out:
# +---------------+---------------+----------+---------------------------+---------------------------+------------+----------------+-------------------------------+----------------+---------------------+-------------------------------+--------------------+----------------+----------------+---------------+----------+----------+----------+----------+----------+----------+-----------+---------------+--------------+---------------+--------------+---------------+--------------+----------------+---------------------------+
# |LastName       |FirstName      |Salutation|Name                       |Company                    |Phone       |MobilePhone     |Email                          |SYS_Mobile__c   |WA_Formatted_Phone__c|Email__c                       |Encrypted_SMobile__c|Mobile_Phone__c |Phone__c        |Mobile3__c     |Mobile4__c|Mobile5__c|Mobile6__c|Mobile7__c|Mobile8__c|Mobile9__c|Mobile10__c|Country_Code__c|First_Phone__c|Second_Phone__c|Third_Phone__c|Fourth_Phone__c|Sixth_Phone__c|Seventh_Phone__c|full_name                  |
# +---------------+---------------+----------+---------------------------+---------------------------+------------+----------------+-------------------------------+----------------+---------------------+-------------------------------+--------------------+----------------+----------------+---------------+----------+----------+----------+----------+----------+----------+-----------+---------------+--------------+---------------+--------------+---------------+--------------+----------------+---------------------------+
# |As Chakravarthi|               |          |As Chakravarthi            |As Chakravarthi            |919962154351|9.19962154351E11|aschakrav@gmail.com            |9.19962154351E11|9.19962154351E11     |aschakrav@gmail.com            |9.19080856509E11    |9.19962154351E11|9.19962154351E11|9.1877809198E11|NaN       |NaN       |NaN       |NaN       |NaN       |NaN       |NaN        |91.0           |
11|NaN            |NaN       |NaN       |NaN       |NaN       |NaN       |NaN       |NaN        |91.0           |9788785078    |NaN            |NaN           |NaN            |NaN           |NaN             |Venkatesan                 |
# |Ramakrishnan   |               |          |Ramakrishnan               |Ramakrishnan               |919444415764|9.19444415764E11|ramakrishnancs61@gmail.com     |9.19444415764E11|9.19444415764E11     |ramakrishnancs61@gmail.com     |NaN                 |9.19444415764E11|9.19444415764E11|NaN            |NaN       |NaN       |NaN       |NaN       |NaN       |NaN       |NaN        |91.0           |9444415764    |NaN            |NaN           |NaN            |NaN           |NaN             |Ramakrishnan               |
# +---------------+---------------+----------+---------------------------+---------------------------+------------+----------------+-------------------------------+----------------+---------------------+-------------------------------+--------------------+----------------+----------------+---------------+----------+----------+----------+----------+----------+----------+-----------+---------------+--------------+---------------+--------------+---------------+--------------+----------------+---------------------------+
# only showing top 20 rows

# %%
import pyspark.sql.functions as F

spark_df = (
    spark_df

    # ------------------------------------------------------------------
    # 0. Name not present (highest priority)
    # ------------------------------------------------------------------
    .withColumn(
        "name_not_present",
        F.when(
            F.col("full_name").isNull() |
            (F.trim(F.col("full_name")) == ""),
            True
        ).otherwise(False)
    )

    # ------------------------------------------------------------------
    # 1. Only dots (ONLY if name is present)
    # ------------------------------------------------------------------
    .withColumn(
        "only_dots_name",
        F.when(
            (F.col("name_not_present") == False) &
            (F.col("full_name").rlike(r"^\s*\.{1,}\s*$")),
            True
        ).otherwise(False)
    )

    # ------------------------------------------------------------------
    # 2. Only single initial (ONLY if name is present)
    # ------------------------------------------------------------------
    .withColumn(
        "only_initial_name",
        F.when(
            (F.col("name_not_present") == False) &
            (F.col("full_name").rlike(r"^\s*\.?[A-Za-z]\.?\s*$")),
            True
        ).otherwise(False)
    )

    # ------------------------------------------------------------------
    # 3. Invalid / blocking names (ONLY if name is present)
    # ------------------------------------------------------------------
    .withColumn(
        "invalid_name",
        F.when(
            (F.col("name_not_present") == False) &
            (F.col("full_name").rlike(
                r"(?i)\b(do not call|dont call|no call|remove|xyz|abcd|abc|test)\b"
            )),
            True
        ).otherwise(False)
    )

    # ------------------------------------------------------------------
    # 4. Final valid flag
    # ------------------------------------------------------------------
    .withColumn(
        "valid_names",
        F.when(
            (F.col("name_not_present") == False) &
            (F.col("only_dots_name") == False) &
            (F.col("only_initial_name") == False) &
            (F.col("invalid_name") == False),
            True
        ).otherwise(False)
    )
)

# %%
from pyspark.sql import functions as F

spark_df = (
    spark_df
    # convert FirstName and LastName to lowercase
    .withColumn("FirstName", F.lower(F.col("FirstName")))
    .withColumn("LastName", F.lower(F.col("LastName")))

    # drop full_name column
    .drop("full_name")
)

# %%
spark_df.show(truncate=False)
# Out:
# +---------------+---------------+----------+---------------------------+---------------------------+------------+----------------+-------------------------------+----------------+---------------------+-------------------------------+--------------------+----------------+----------------+---------------+----------+----------+----------+----------+----------+----------+-----------+---------------+--------------+---------------+--------------+---------------+--------------+----------------+----------------+--------------+-----------------+------------+-----------+
# |LastName       |FirstName      |Salutation|Name                       |Company                    |Phone       |MobilePhone     |Email                          |SYS_Mobile__c   |WA_Formatted_Phone__c|Email__c                       |Encrypted_SMobile__c|Mobile_Phone__c |Phone__c        |Mobile3__c     |Mobile4__c|Mobile5__c|Mobile6__c|Mobile7__c|Mobile8__c|Mobile9__c|Mobile10__c|Country_Code__c|First_Phone__c|Second_Phone__c|Third_Phone__c|Fourth_Phone__c|Sixth_Phone__c|Seventh_Phone__c|name_not_present|only_dots_name|only_initial_name|invalid_name|valid_names|
+-----------+
# only showing top 20 rows

# %%
from pyspark.sql import functions as F
from pyspark.sql.window import Window

EMAIL_REGEX = (
    r'^(?=.{1,254}$)(?=.{1,64}@)'
    r'[A-Za-z0-9_%+-]+(\.[A-Za-z0-9_%+-]+)*'
    r'@'
    r'[A-Za-z0-9-]+(\.[A-Za-z0-9-]+)*\.[A-Za-z]{2,}$'
)

# Preserve original order
spark_df = spark_df.withColumn("_row_order", F.monotonically_increasing_id())

# --------------------------------------------------
# 1. Email not present
# --------------------------------------------------
spark_df = spark_df.withColumn(
    "email_not_present",
    F.when(
        F.col("Email").isNull() |
        (F.trim(F.col("Email")) == "") |
        (F.lower(F.trim(F.col("Email"))) == "nan"),
        True
    ).otherwise(False)
)

# --------------------------------------------------
# 2. Invalid email format (regex only)
# --------------------------------------------------
spark_df = spark_df.withColumn(
    "invalid_email_format",
    F.when(
        (F.col("email_not_present") == False) &
        (~F.trim(F.col("Email")).rlike(EMAIL_REGEX)),
        True
    ).otherwise(False)
)

# --------------------------------------------------
# 3. Duplicate email (case-insensitive)
# --------------------------------------------------
email_window = Window.partitionBy(F.lower(F.trim(F.col("Email"))))

spark_df = spark_df.withColumn(
    "duplicate_email",
    F.when(
        (F.col("email_not_present") == False) &
        (F.col("invalid_email_format") == False) &
        (F.count("*").over(email_window) > 1),
        True
    ).otherwise(False)
)

# --------------------------------------------------
# 4. Final valid email flag
# --------------------------------------------------
spark_df = spark_df.withColumn(
    "valid_email",
    F.when(
        (F.col("email_not_present") == True) |
        (F.col("invalid_email_format") == True) |
        (F.col("duplicate_email") == True),
        False
    ).otherwise(True)
)

# --------------------------------------------------
# Restore original order
# --------------------------------------------------
spark_df = spark_df.orderBy("_row_order").drop("_row_order")

# %%
spark_df.show(10,truncate=False)
# Out:
# +---------------+---------+----------+---------------+---------------+------------+----------------+-------------------------+----------------+---------------------+-------------------------+--------------------+----------------+----------------+---------------+----------+----------+----------+----------+----------+----------+-----------+---------------+--------------+---------------+--------------+---------------+--------------+----------------+----------------+--------------+-----------------+------------+-----------+-----------------+--------------------+---------------+-----------+
# |LastName       |FirstName|Salutation|Name           |Company        |Phone       |MobilePhone     |Email                    |SYS_Mobile__c   |WA_Formatted_Phone__c|Email__c                 |Encrypted_SMobile__c|Mobile_Phone__c |Phone__c        |Mobile3__c     |Mobile4__c|Mobile5__c|Mobile6__c|Mobile7__c|Mobile8__c|Mobile9__c|Mobile10__c|Country_Code__c|First_Phone__c|Second_Phone__c|Third_Phone__c|Fourth_Phone__c|Sixth_Phone__c|Seventh_Phone__c|name_not_present|only_dots_name|only_initial_name|invalid_name|valid_names|email_not_present|invalid_email_format|duplicate_email|valid_email|
# +---------------+---------+----------+---------------+---------------+------------+----------------+-------------------------+----------------+---------------------+-------------------------+--------------------+----------------+----------------+---------------+----------+----------+----------+----------+----------+----------+-----------+---------------+--------------+---------------+--------------+---------------+--------------+----------------+----------------+--------------+-----------------+------------+-----------+-----------------+--------------------+---------------+-----------+
# |as chakravarthi|         |          |As Chakravarthi|As Chakravarthi|919962154351|9.19962154351E11|aschakrav@gmail.com      |9.19962154351E11|9.19962154351E11     |aschakrav@gmail.com      |9.19080856509E11    |9.19962154351E11|9.19962154351E11|9.1877809198E11|NaN       |NaN       |NaN       |NaN       |NaN       |NaN       |NaN        |91.0           |9962154351    |9.080856509E9  |8.77809198E9  |NaN            |NaN           |NaN             |false           |false         |false            |false       |true       |false            |false               |false          |true       |
# |raveendra      |meda     |          |Meda Raveendra |Meda Raveendra |919962041716|9.19962041716E11|mrreddy@ramcadds.in      |9.19962041716E11|9.19962041716E11     |mrreddy@ramcadds.in      |NaN                 |9.19962041716E11|9.19962041716E11|NaN            |NaN       |NaN       |NaN       |NaN       |NaN       |NaN       |NaN        |91.0           |9962041716    |NaN            |NaN           |NaN            |NaN           |NaN             |false           |false         |false            |false       |true       |false            |false               |false          |true       |
# |kannan         |         |Mr        |Kannan         |Kannan         |918189923399|9.18189923399E11|kannan.ican1891@gmail.com|9.18189923399E11|9.18189923399E11     |kannan.ican1891@gmail.com|NaN                 |9.18189923399E11|9.18189923399E11|NaN            |NaN       |NaN       |NaN       |NaN       |NaN       |NaN       |NaN        |91.0           |8189923399    |NaN            |NaN           |NaN            |NaN           |NaN             |false           |false         |false            |false       |true       |false            |false               |false          |true       |
# |ramyaa         |         |Mr        |Ramyaa         |Ramyaa         |919962746446|9.19962746446E11|ramyaa.doc@gmail.com     |9.19962746446E11|9.19962746446E11     |ramyaa.doc@gmail.com     |9.19003087775E11    |9.19962746446E11|9.19962746446E11|NaN            |NaN       |NaN       |NaN       |NaN       |NaN       |NaN       |NaN        |91.0           |9962746446    |9.003087775E9  |NaN           |NaN            |NaN           |NaN             |false           |false         |false            |false       |true       |false            |false               |false          |true       |
# |vasan.k        |         |Mr        |Vasan.K        |Vasan.K        |918939149522|9.18939149522E11|vasankm@yahoo.com        |9.18939149522E11|9.18939149522E11     |vasankm@yahoo.com        |NaN                 |9.18939149522E11|9.18939149522E11|NaN            |NaN       |NaN       |NaN       |NaN       |NaN       |NaN       |NaN        |91.0           |8939149522    |NaN            |NaN           |NaN            |NaN           |NaN             |false           |false         |false            |false       |true       |false            |false               |false          |true       |
# |sundar         |         |Mr        |sundar         |sundar         |919962502711|9.19962502711E11|ksundar2001@gmail.com    |9.19962502711E11|9.19962502711E11     |ksundar2001@gmail.com    |NaN                 |9.19962502711E11|9.19962502711E11|NaN            |NaN       |NaN       |NaN       |NaN       |NaN       |NaN       |NaN        |91.0           |9962502711    |NaN            |NaN           |NaN            |NaN           |NaN             |false           |false         |false            |false       |true       |false            |false               |false          |true       |
# |pandiyan       |         |Mr        |Pandiyan       |Pandiyan       |919790947384|9.19790947384E11|acp3012@gmail.com        |9.19790947384E11|9.19790947384E11     |acp3012@gmail.com        |NaN                 |9.19790947384E11|9.19790947384E11|NaN            |NaN       |NaN       |NaN       |NaN       |NaN       |NaN       |NaN        |91.0           |9790947384    |NaN            |NaN           |NaN            |NaN           |NaN             |false           |false         |false            |false       |true       |false            |false               |false          |true       |
# |k.uma          |         |Mr        |K.Uma          |K.Uma          |919840891528|9.19840891528E11|kuma189@yahoo.com        |9.19840891528E11|9.19840891528E11     |kuma189@yahoo.com        |NaN                 |9.19840891528E11|9.19840891528E11|NaN            |NaN       |NaN       |NaN       |NaN       |NaN       |NaN       |NaN        |91.0           |9840891528    |NaN            |NaN           |NaN            |NaN           |NaN             |false           |false         |false            |false       |true       |false            |false               |false          |true       |
# |vinodh kumar   |         |          |Vinodh Kumar   |Vinodh Kumar   |919940194192|9.19940194192E11|vinoths99401@gmail.com   |9.19940194192E11|9.19940194192E11     |vinoths99401@gmail.com   |NaN                 |9.19940194192E11|9.19940194192E11|NaN            |NaN       |NaN       |NaN       |NaN       |NaN       |NaN       |NaN        |91.0           |9940194192    |NaN            |NaN           |NaN            |NaN           |NaN             |false           |false         |false            |false       |true       |false            |false               |false          |true       |
# |soundar        |         |          |Soundar        |Soundar        |919677023477|9.19677023477E11|phyraj2008@gmail.com     |9.19677023477E11|9.19677023477E11     |phyraj2008@gmail.com     |NaN                 |9.19677023477E11|9.19677023477E11|NaN            |NaN       |NaN       |NaN       |NaN       |NaN       |NaN       |NaN        |91.0           |9677023477    |NaN            |NaN           |NaN            |NaN           |NaN             |false           |false         |false            |false       |true       |false            |false               |false          |true       |
# +---------------+---------+----------+---------------+---------------+------------+----------------+-------------------------+----------------+---------------------+-------------------------+--------------------+----------------+----------------+---------------+----------+----------+----------+----------+----------+----------+-----------+---------------+--------------+---------------+--------------+---------------+--------------+----------------+----------------+--------------+-----------------+------------+-----------+-----------------+--------------------+---------------+-----------+
# only showing top 10 rows

# %%
df = spark_df.toPandas()

# %%
df.to_csv("output3.csv", index=False)
